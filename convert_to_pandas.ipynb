# %%
import json
import numpy as np
import pandas as pd

file_path = "/home/kyumin/work/preprocessing/BF-PSR-Framework/JsonData/PJZC.txt"

df = pd.DataFrame()
with open(file_path) as json_file:
    conversations = json.load(json_file)
    for p in conversations['conversation']:
        messages = p['messages']
        df_message = pd.DataFrame(messages)
        m_id = 0
        df_temp = pd.DataFrame()
        # print(df_message.shape[0])
        for j in range(df_message.shape[0]): 
            df_temp.loc[j, 'source'] = p['source']
            df_temp.loc[j, 'label'] = p['label']
            df_temp.loc[j, 'message_idx'] = p['id']
        df_temp = pd.concat([df_temp, df_message], axis=1)
        # print(df_temp.shape)
        df = pd.concat([df, df_temp], axis=0)
        # print(df.shape)
        m_id += 1
        

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 file_path = "/home/kyumin/work/preprocessing/datasets/BF-PSR-Framework/JsonData/PJZC.txt"
#       7 df = pd.DataFrame()
# ----> 8 with open(file_path) as json_file:
#       9     conversations = json.load(json_file)
#      10     for p in conversations['conversation']:
#
# File ~/anaconda3/envs/preprocessing/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/kyumin/work/preprocessing/datasets/BF-PSR-Framework/JsonData/PJZC.txt'

# %%
df
# Out:
#        source label  message_idx     author   time  \
# 0    PJ chats     1          0.0      decoy  14:40
# 1    PJ chats     1          0.0  Billy Joe  14:40
# 2    PJ chats     1          0.0  Billy Joe  14:41
# 3    PJ chats     1          0.0      decoy  14:41
# 4    PJ chats     1          0.0  Billy Joe  14:42
# ..        ...   ...          ...        ...    ...
# 7   ZIG chats     0      13821.0     ikskuh  19:35
# 8   ZIG chats     0      13821.0     ikskuh  19:35
# 9   ZIG chats     0      13821.0     ikskuh  19:35
# 10  ZIG chats     0      13821.0    Swahili  19:41
# 11  ZIG chats     0      13821.0    Swahili  19:50
#
#                                                  text
# 0                                        Hey Its Mads
# 1                                           Hey babes
# 2                      Almost done with work. So glad
# 3                            Hey:) that's good right?
# 4                                                 Yea
# ..                                                ...
# 7             pub fn new(input: []const u8) *Foobar {
# 8                                                  do
# 9              pub fn new(input: []const u8) Foobar {
# 10         Thanks for looking! I see, I'll try again!
# 11  Gosh! Thanks a lot! That worked! I should have...
#
# [226612 rows x 6 columns]

# %%
df['time'] = df['time'].apply(str)
df['time'] = df['time'].apply(lambda x: f'"{x}"') # 이거 안하면 엑셀에서 이상하게 읽어버림림
df['message_idx'] = df['message_idx'].apply(int)
df
# Out:
#        source label  message_idx     author     time  \
# 0    PJ chats     1            0      decoy  "14:40"
# 1    PJ chats     1            0  Billy Joe  "14:40"
# 2    PJ chats     1            0  Billy Joe  "14:41"
# 3    PJ chats     1            0      decoy  "14:41"
# 4    PJ chats     1            0  Billy Joe  "14:42"
# ..        ...   ...          ...        ...      ...
# 7   ZIG chats     0        13821     ikskuh  "19:35"
# 8   ZIG chats     0        13821     ikskuh  "19:35"
# 9   ZIG chats     0        13821     ikskuh  "19:35"
# 10  ZIG chats     0        13821    Swahili  "19:41"
# 11  ZIG chats     0        13821    Swahili  "19:50"
#
#                                                  text
# 0                                        Hey Its Mads
# 1                                           Hey babes
# 2                      Almost done with work. So glad
# 3                            Hey:) that's good right?
# 4                                                 Yea
# ..                                                ...
# 7             pub fn new(input: []const u8) *Foobar {
# 8                                                  do
# 9              pub fn new(input: []const u8) Foobar {
# 10         Thanks for looking! I see, I'll try again!
# 11  Gosh! Thanks a lot! That worked! I should have...
#
# [226612 rows x 6 columns]

# %%
df.to_csv("PJZ2.csv", index=False, encoding='utf-8')
